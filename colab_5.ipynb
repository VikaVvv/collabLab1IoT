# %% [markdown]
# <a href="https://colab.research.google.com/github/VikaVvv/collabLab1IoT/blob/main/colab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/collabLab1.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    ;;;;;;
# 0  ;;;;;;

# %%
import requests
url = 'https://raw.githubusercontent.com/VikaVvv/BSU_OS_Labs/144ab103aba0833354accee7c58d46ae6445b05b/collabLab1.csv'
r = requests.get(url)
print(r.text)
# Out:
# ;;;;;;
# ;;;;;;

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/photoLab.png')

# %% [markdown]
# ![Красивый кот](https://i.pinimg.com/736x/4f/05/33/4f05339457fd103288abbf945d9e697b.jpg)
